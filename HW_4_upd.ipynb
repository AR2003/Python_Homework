# %% [markdown]
# # Домашнее задание "Функции одной переменной".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# ### Задание 1

# %% [markdown]
# Посчитайте значение первой и второй производной функции:
#
# $f(x) = x^5 + 4sin(2x) + cos(3x+3)$
#
# В точке x = 1.

# %%
import sympy as sym
x = sym.Symbol('x')
y = 𝑥**5+4*sym.sin(2*𝑥)+sym.cos(3*𝑥+3)

yfirst = y.diff(x)
print(yfirst)
ysecond = yfirst.diff(x)
print(ysecond)
# Out:
# 5*x**4 - 3*sin(3*x + 3) + 8*cos(2*x)
# 20*x**3 - 16*sin(2*x) - 9*cos(3*x + 3)

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Постройте график первой и второй производной функции:
#
# $f(x) = sin^5(2x+1)$
#
# На отрезке [-5; 5].

# %%
import numpy as np
import matplotlib.pyplot as plt

y=(sym.sin(2*x+1))**5
yfirst = y.diff(x)
print(yfirst)
ysecond = yfirst.diff(x)
print(ysecond)


def function(f,arg):
    fr=f
    return fr.subs(x,arg)

xg=list(np.arange(-5,5,0.1))
yg=[]
for i in xg:   
    yg.append(function(yfirst,i)) 

plt.plot(xg,yg,label="Первая производная")
plt.xlabel('x')
plt.ylabel('y')
plt.title('Производные функции ')
    
yg=[]
for i in xg:   
    yg.append(function(ysecond,i))     
    
plt.plot(xg,yg,label="Вторая производная")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# 10*sin(2*x + 1)**4*cos(2*x + 1)
# -20*sin(2*x + 1)**5 + 80*sin(2*x + 1)**3*cos(2*x + 1)**2
